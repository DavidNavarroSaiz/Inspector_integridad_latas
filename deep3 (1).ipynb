# %%
import tensorflow as tf
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
# from keras.layers import Dense
from tensorflow.keras.layers import Dropout
from keras.callbacks import ModelCheckpoint
from keras.callbacks import Callback, ReduceLROnPlateau, EarlyStopping
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd 
from keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
import seaborn as sns
import math
import keras
from keras.constraints import max_norm
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense
from tensorflow.keras import models
# %matplotlib inline

# %%
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

# %%
# import keras

# config = tf.ConfigProto( device_count = {'GPU': 1 , 'CPU': 56} )
# sess = tf.Session(config=config) 
# keras.backend.set_session(sess)

# %%
# # Splitting images Train/Val/Test

# import split_folders
# # Split with a ratio.
# # To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
# split_folders.ratio('dataset/all_cameras', output="dataset/all_split_2", seed=45, ratio=(.9, .10)) # default values

# %%
base_dir = 'dataset/all_cameras_splitted'
test_dir =  os.path.join(base_dir, 'test')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'Val')

# Directory with our training pictures
train_OK_dir = os.path.join(train_dir, 'OK')
train_NOT_OK_dir = os.path.join(train_dir, 'NOT_OK')

# Directory with our validation pictures
validation_OK_dir = os.path.join(validation_dir, 'OK')
validation_NOT_OK_dir = os.path.join(validation_dir, 'NOT_OK')
train_OK_fnames = os.listdir( train_OK_dir )
train_NOT_OK_fnames = os.listdir( train_NOT_OK_dir )

# print(train_cat_fnames[:10])
# print(train_dog_fnames[:10])

# %%
# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

pic_index = 0 # Index for iterating over images
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index+=8

next_OK_pix = [os.path.join(train_OK_dir, fname) 
                for fname in train_OK_fnames[ pic_index-8:pic_index] 
               ]

next_NOT_OK_pix = [os.path.join(train_NOT_OK_dir, fname) 
                for fname in train_NOT_OK_fnames[ pic_index-8:pic_index]
               ]

for i, img_path in enumerate(next_OK_pix+next_NOT_OK_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
#   print(img.shape)  
  plt.imshow(img, 'gray')

# %%
# All images will be rescaled by 1./255.
train_datagen = ImageDataGenerator(
      rescale=1/255,
#       rotation_range=40,
#       width_shift_range=0.2,
#       height_shift_range=0.2,
#       fill_mode='nearest',
#       shear_range=0.2,
#       zoom_range=0.2,
#       horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1/255)
train_generator = train_datagen.flow_from_directory(
        train_dir,  # This is the source directory for training images

        ### En esta linea de codigo se cambia el tamaño de la imagen

        target_size=(256, 256),  # All images will be resized 

        ####

        batch_size=128,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Flow training images in batches of 128 using train_datagen generator
validation_generator = val_datagen.flow_from_directory(
        validation_dir,  # This is the source directory for training images

        ##Tamaño de imagen del validation dataset


        target_size=(256, 256),  # All images will be resized 
        ###


        batch_size=128,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Out:
# Found 16761 images belonging to 2 classes.
# Found 3351 images belonging to 2 classes.

# %%
# def plots(ims, figsize=(12,6), rows=3, interp=False, titles=None):
#     if type(ims[0]) is np.ndarray:
#         ims = np.array(ims).astype(np.uint8)
#         if (ims.shape[-1] != 3):
#             ims = ims[:, :, ::-1]
            
#     f = plt.figure(figsize=figsize)
#     cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
#     for i in range(len(ims)):
#         sp = f.add_subplot(rows, cols, i+1)
#         sp.axis('Off')
#         if titles is not None:
#             sp.set_title(titles[i], fontsize=16)
#             ims[i] = np.reshape(ims[i],((128,128)))
#         plt.imshow(ims[i], interpolation=None if interp else 'none')
#         print(ims[i].shape)
# imgs, labels = next(train_generator)

# plots(imgs)

# %%
# with tf.device('/cpu:0'):
classifier = Sequential()
classifier.add(Convolution2D(32,(5,5),input_shape=(256, 256,3),activation= "relu",padding="same",kernel_constraint=max_norm(3))) ##
#     classifier.add(BatchNormalization())
classifier.add(MaxPooling2D(pool_size = (2,2)))
#     classifier.add(Convolution2D(32,(3,3),activation='relu',padding="same"))
#     classifier.add(BatchNormalization())
#     classifier.add(Convolution2D(32,(3,3),activation='relu',padding="same"))
#     classifier.add(BatchNormalization())
#     classifier.add(Convolution2D(32,(3,3),activation='relu',padding="same"))
#     classifier.add(BatchNormalization())
#     classifier.add(MaxPooling2D(2))
#     classifier.add(Convolution2D(64,(3,3),activation='relu',padding="same"))
#     classifier.add(BatchNormalization())
classifier.add(Convolution2D(64,(3,3),activation='relu',padding="same"))
#     classifier.add(BatchNormalization())
classifier.add(MaxPooling2D(2))
classifier.add(Convolution2D(128,(3,3),activation='relu',padding="same"))
classifier.add(MaxPooling2D(2))
#     classifier.add(BatchNormalization())
# classifier.add(Convolution2D(128,(3,3),activation='relu',padding="same"))
#     classifier.add(BatchNormalization())
classifier.add(Convolution2D(256,(3,3),activation='relu',padding="same"))
classifier.add(BatchNormalization())
classifier.add(MaxPooling2D(2))
#     classifier.add(Convolution2D(256,(3,3),activation='relu',padding="same"))
#     classifier.add(BatchNormalization())
classifier.add(Convolution2D(256,(3,3),activation='relu',padding="same",kernel_constraint=max_norm(3)))
#     classifier.add(BatchNormalization())
classifier.add(MaxPooling2D(2))
classifier.add(Convolution2D(512,(3,3),activation='relu',padding="same"))
# classifier.add(BatchNormalization())
classifier.add(MaxPooling2D(2))
#     classifier.add(Convolution2D(512,(3,3),activation='relu',padding="same"))
# classifier.add(BatchNormalization())
# classifier.add(MaxPooling2D(2))

classifier.add(Flatten())
#     classifier.add(Dense(units=2048,activation='relu'))
# # classifier.add(Dropout(0.5))
classifier.add(Dense(256, activation='relu',kernel_initializer='random_normal',
    bias_initializer='zeros'))
classifier.add(Dropout(0.4))
classifier.add(Dense(128, activation='relu',kernel_initializer='random_normal',
    bias_initializer='zeros'))
classifier.add(Dropout(0.4))
classifier.add(Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l1_l2(0.01),kernel_initializer='random_normal',
    bias_initializer='zeros'))
#     classifier.add(Dense(units=128,activation='relu'))
classifier.add(Dropout(0.2))
classifier.add(Dense(units=16,activation='relu',kernel_initializer='random_normal',
    bias_initializer='zeros'))
#     classifier.add(Dense(units=32,activation='relu'))
#     classifier.add(Dense(units=16,activation='relu'))
#     classifier.add(Dense(units=8,activation='relu'))
classifier.add(Dense(units=1,activation='sigmoid'))

# classifier.compile(optimizer= 'adam',loss = 'binary_crossentropy',metrics= ['accuracy'])


sgd = keras.optimizers.SGD(lr=0.01)
classifier.compile(loss="binary_crossentropy", optimizer=sgd, metrics=["accuracy"])

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       295168
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 4,300,833
# Trainable params: 4,300,321
# Non-trainable params: 512
# _________________________________________________________________

# %%
# from tensorflow.python.client import device_lib 
# print(device_lib.list_local_devices())

# %%
with tf.device('/cpu:0'):
    filepath="10-improvement-{epoch:02d}-{val_accuracy:.2f}.h5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

    reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', mode="max", factor = 0.7, 
         patience = 5, verbose = 1, min_delta =0.00001)
    early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, mode='auto')

    callbacks = [reduce_lr,checkpoint,early_stop]

    batch_size = 128

    history = classifier.fit(train_generator,
                                       steps_per_epoch = math.ceil(train_generator.samples//batch_size),
                                  validation_data=validation_generator,  
                                       validation_steps=math.ceil(validation_generator.samples//batch_size),
                                  epochs=100,workers=-1, 
                                use_multiprocessing=True, shuffle=True, callbacks=callbacks
                                      )
# Out:
# Epoch 1/100
# 157/157 [==============================] - 2158s 14s/step - loss: 3.7440 - accuracy: 0.6543 - val_loss: 2.8378 - val_accuracy: 0.7413
#
# Epoch 00001: val_accuracy improved from -inf to 0.74127, saving model to 10-improvement-01-0.74.h5
# Epoch 2/100
# 157/157 [==============================] - 2206s 14s/step - loss: 2.4313 - accuracy: 0.7430 - val_loss: 1.8261 - val_accuracy: 0.7937
#
# Epoch 00002: val_accuracy improved from 0.74127 to 0.79366, saving model to 10-improvement-02-0.79.h5
# Epoch 3/100
# 157/157 [==============================] - 2253s 14s/step - loss: 1.5436 - accuracy: 0.8092 - val_loss: 1.1650 - val_accuracy: 0.8396
#
# Epoch 00003: val_accuracy improved from 0.79366 to 0.83961, saving model to 10-improvement-03-0.84.h5
# Epoch 4/100
# 157/157 [==============================] - 2142s 14s/step - loss: 0.9921 - accuracy: 0.8279 - val_loss: 0.7209 - val_accuracy: 0.8428
#
# Epoch 00004: val_accuracy improved from 0.83961 to 0.84283, saving model to 10-improvement-04-0.84.h5
# Epoch 5/100
# 157/157 [==============================] - 2227s 14s/step - loss: 0.6753 - accuracy: 0.8395 - val_loss: 0.6111 - val_accuracy: 0.7642
#
# Epoch 00005: val_accuracy did not improve from 0.84283
# Epoch 6/100
# 157/157 [==============================] - 2194s 14s/step - loss: 0.5030 - accuracy: 0.8545 - val_loss: 0.3881 - val_accuracy: 0.8938
#
# Epoch 00006: val_accuracy improved from 0.84283 to 0.89384, saving model to 10-improvement-06-0.89.h5
# Epoch 7/100
# 157/157 [==============================] - 2274s 14s/step - loss: 0.4081 - accuracy: 0.8727 - val_loss: 0.3384 - val_accuracy: 0.8906
#
# Epoch 00007: val_accuracy did not improve from 0.89384
# Epoch 8/100
# 157/157 [==============================] - 2246s 14s/step - loss: 0.3613 - accuracy: 0.8816 - val_loss: 0.3033 - val_accuracy: 0.9049
#
# Epoch 00008: val_accuracy improved from 0.89384 to 0.90487, saving model to 10-improvement-08-0.90.h5
# Epoch 9/100
# 157/157 [==============================] - 2131s 14s/step - loss: 0.3269 - accuracy: 0.8913 - val_loss: 0.3213 - val_accuracy: 0.8971
#
# Epoch 00009: val_accuracy did not improve from 0.90487
# Epoch 10/100
# 157/157 [==============================] - 8606s 55s/step - loss: 0.2967 - accuracy: 0.9080 - val_loss: 0.3465 - val_accuracy: 0.8658
#
# Epoch 00010: val_accuracy did not improve from 0.90487
# Epoch 11/100
# 157/157 [==============================] - 2127s 14s/step - loss: 0.2921 - accuracy: 0.9085 - val_loss: 0.2568 - val_accuracy: 0.9223
#
# Epoch 00011: val_accuracy improved from 0.90487 to 0.92233, saving model to 10-improvement-11-0.92.h5
# Epoch 12/100
# 157/157 [==============================] - 2128s 14s/step - loss: 0.2641 - accuracy: 0.9202 - val_loss: 0.2445 - val_accuracy: 0.9200
#
# Epoch 00012: val_accuracy did not improve from 0.92233
# Epoch 13/100
# 157/157 [==============================] - 2133s 14s/step - loss: 0.2592 - accuracy: 0.9211 - val_loss: 0.2445 - val_accuracy: 0.9214
#
# Epoch 00013: val_accuracy did not improve from 0.92233
# Epoch 14/100
# 157/157 [==============================] - 2135s 14s/step - loss: 0.2537 - accuracy: 0.9236 - val_loss: 0.2251 - val_accuracy: 0.9352
#
# Epoch 00014: val_accuracy improved from 0.92233 to 0.93520, saving model to 10-improvement-14-0.94.h5
# Epoch 15/100
# 157/157 [==============================] - 2132s 14s/step - loss: 0.2373 - accuracy: 0.9293 - val_loss: 0.3358 - val_accuracy: 0.8741
#
# Epoch 00015: val_accuracy did not improve from 0.93520
# Epoch 16/100
# 157/157 [==============================] - 2159s 14s/step - loss: 0.2230 - accuracy: 0.9379 - val_loss: 0.2902 - val_accuracy: 0.8925
#
# Epoch 00016: val_accuracy did not improve from 0.93520
# Epoch 17/100
# 157/157 [==============================] - 2133s 14s/step - loss: 0.2064 - accuracy: 0.9425 - val_loss: 0.2140 - val_accuracy: 0.9329
#
# Epoch 00017: val_accuracy did not improve from 0.93520
# Epoch 18/100
# 157/157 [==============================] - 2118s 13s/step - loss: 0.2085 - accuracy: 0.9396 - val_loss: 0.1928 - val_accuracy: 0.9389
#
# Epoch 00018: val_accuracy improved from 0.93520 to 0.93888, saving model to 10-improvement-18-0.94.h5
# Epoch 19/100
# 157/157 [==============================] - 2118s 13s/step - loss: 0.1962 - accuracy: 0.9447 - val_loss: 0.1867 - val_accuracy: 0.9472
#
# Epoch 00019: val_accuracy improved from 0.93888 to 0.94715, saving model to 10-improvement-19-0.95.h5
# Epoch 20/100
# 157/157 [==============================] - 2126s 14s/step - loss: 0.1964 - accuracy: 0.9469 - val_loss: 0.1952 - val_accuracy: 0.9472
#
# Epoch 00020: val_accuracy did not improve from 0.94715
# Epoch 21/100
# 157/157 [==============================] - 2124s 14s/step - loss: 0.1754 - accuracy: 0.9566 - val_loss: 0.1764 - val_accuracy: 0.9485
#
# Epoch 00021: val_accuracy improved from 0.94715 to 0.94853, saving model to 10-improvement-21-0.95.h5
# Epoch 22/100
# 157/157 [==============================] - 2125s 14s/step - loss: 0.1638 - accuracy: 0.9580 - val_loss: 0.1749 - val_accuracy: 0.9513
#
# Epoch 00022: val_accuracy improved from 0.94853 to 0.95129, saving model to 10-improvement-22-0.95.h5
# Epoch 23/100
# 157/157 [==============================] - 2134s 14s/step - loss: 0.1906 - accuracy: 0.9459 - val_loss: 0.1741 - val_accuracy: 0.9504
#
# Epoch 00023: val_accuracy did not improve from 0.95129
# Epoch 24/100
# 157/157 [==============================] - 2132s 14s/step - loss: 0.1658 - accuracy: 0.9594 - val_loss: 0.1977 - val_accuracy: 0.9458
#
# Epoch 00024: val_accuracy did not improve from 0.95129
# Epoch 25/100
# 157/157 [==============================] - 2134s 14s/step - loss: 0.1606 - accuracy: 0.9594 - val_loss: 0.1723 - val_accuracy: 0.9531
#
# Epoch 00025: val_accuracy improved from 0.95129 to 0.95312, saving model to 10-improvement-25-0.95.h5
# Epoch 26/100
# 157/157 [==============================] - 2126s 14s/step - loss: 0.1425 - accuracy: 0.9664 - val_loss: 0.1741 - val_accuracy: 0.9504
#
# Epoch 00026: val_accuracy did not improve from 0.95312
# Epoch 27/100
# 157/157 [==============================] - 2126s 14s/step - loss: 0.1400 - accuracy: 0.9657 - val_loss: 0.1596 - val_accuracy: 0.9577
#
# Epoch 00027: val_accuracy improved from 0.95312 to 0.95772, saving model to 10-improvement-27-0.96.h5
# Epoch 28/100
# 157/157 [==============================] - 2136s 14s/step - loss: 0.1390 - accuracy: 0.9682 - val_loss: 0.2059 - val_accuracy: 0.9403
#
# Epoch 00028: val_accuracy did not improve from 0.95772
# Epoch 29/100
# 157/157 [==============================] - 2141s 14s/step - loss: 0.1257 - accuracy: 0.9718 - val_loss: 0.7592 - val_accuracy: 0.7385
#
# Epoch 00029: val_accuracy did not improve from 0.95772
# Epoch 30/100
# 157/157 [==============================] - 2134s 14s/step - loss: 0.1300 - accuracy: 0.9713 - val_loss: 0.1777 - val_accuracy: 0.9536
#
# Epoch 00030: val_accuracy did not improve from 0.95772
# Epoch 31/100
# 157/157 [==============================] - 2126s 14s/step - loss: 0.1304 - accuracy: 0.9689 - val_loss: 0.1855 - val_accuracy: 0.9467
#
# Epoch 00031: val_accuracy did not improve from 0.95772
# Epoch 32/100
# 157/157 [==============================] - 2126s 14s/step - loss: 0.1154 - accuracy: 0.9721 - val_loss: 0.1594 - val_accuracy: 0.9499
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.006999999843537807.
#
# Epoch 00032: val_accuracy did not improve from 0.95772
# Epoch 33/100
# 157/157 [==============================] - 2129s 14s/step - loss: 0.1056 - accuracy: 0.9773 - val_loss: 0.1468 - val_accuracy: 0.9586
#
# Epoch 00033: val_accuracy improved from 0.95772 to 0.95864, saving model to 10-improvement-33-0.96.h5
# Epoch 34/100
# 157/157 [==============================] - 2120s 14s/step - loss: 0.0942 - accuracy: 0.9821 - val_loss: 0.1583 - val_accuracy: 0.9586
#
# Epoch 00034: val_accuracy did not improve from 0.95864
# Epoch 35/100
# 157/157 [==============================] - 4489s 29s/step - loss: 0.0960 - accuracy: 0.9811 - val_loss: 0.1820 - val_accuracy: 0.9517
#
# Epoch 00035: val_accuracy did not improve from 0.95864
# Epoch 36/100
# 157/157 [==============================] - 2209s 14s/step - loss: 0.0938 - accuracy: 0.9823 - val_loss: 0.1428 - val_accuracy: 0.9577
#
# Epoch 00036: val_accuracy did not improve from 0.95864
# Epoch 37/100
# 157/157 [==============================] - 2205s 14s/step - loss: 0.0872 - accuracy: 0.9834 - val_loss: 0.1413 - val_accuracy: 0.9632
#
# Epoch 00037: val_accuracy improved from 0.95864 to 0.96324, saving model to 10-improvement-37-0.96.h5
# Epoch 38/100
# 157/157 [==============================] - 2268s 14s/step - loss: 0.0861 - accuracy: 0.9827 - val_loss: 0.1538 - val_accuracy: 0.9563
#
# Epoch 00038: val_accuracy did not improve from 0.96324
# Epoch 39/100
# 157/157 [==============================] - 2253s 14s/step - loss: 0.0872 - accuracy: 0.9830 - val_loss: 0.1478 - val_accuracy: 0.9605
#
# Epoch 00039: val_accuracy did not improve from 0.96324
# Epoch 40/100
# 157/157 [==============================] - 2194s 14s/step - loss: 0.0842 - accuracy: 0.9824 - val_loss: 0.1632 - val_accuracy: 0.9591
#
# Epoch 00040: val_accuracy did not improve from 0.96324
# Epoch 41/100
# 157/157 [==============================] - 2158s 14s/step - loss: 0.0785 - accuracy: 0.9861 - val_loss: 0.1487 - val_accuracy: 0.9605
#
# Epoch 00041: val_accuracy did not improve from 0.96324
# Epoch 42/100
# 157/157 [==============================] - 2151s 14s/step - loss: 0.0757 - accuracy: 0.9871 - val_loss: 0.1502 - val_accuracy: 0.9600
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.004899999825283885.
#
# Epoch 00042: val_accuracy did not improve from 0.96324
# Epoch 43/100
# 157/157 [==============================] - 2178s 14s/step - loss: 0.0644 - accuracy: 0.9893 - val_loss: 0.1503 - val_accuracy: 0.9550
#
# Epoch 00043: val_accuracy did not improve from 0.96324
# Epoch 44/100
# 157/157 [==============================] - 2238s 14s/step - loss: 0.0632 - accuracy: 0.9908 - val_loss: 0.1463 - val_accuracy: 0.9600
#
# Epoch 00044: val_accuracy did not improve from 0.96324
# Epoch 45/100
# 157/157 [==============================] - 2625s 17s/step - loss: 0.0672 - accuracy: 0.9891 - val_loss: 0.1471 - val_accuracy: 0.9628
#
# Epoch 00045: val_accuracy did not improve from 0.96324
# Epoch 46/100
# 157/157 [==============================] - 2512s 16s/step - loss: 0.0612 - accuracy: 0.9897 - val_loss: 0.1451 - val_accuracy: 0.9623
#
# Epoch 00046: val_accuracy did not improve from 0.96324
# Epoch 47/100
# 157/157 [==============================] - 2292s 15s/step - loss: 0.0607 - accuracy: 0.9905 - val_loss: 0.1470 - val_accuracy: 0.9600
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0034300000406801696.
#
# Epoch 00047: val_accuracy did not improve from 0.96324
# Epoch 48/100
# 157/157 [==============================] - 2249s 14s/step - loss: 0.0543 - accuracy: 0.9940 - val_loss: 0.1530 - val_accuracy: 0.9614
#
# Epoch 00048: val_accuracy did not improve from 0.96324
# Epoch 49/100
# 157/157 [==============================] - 2245s 14s/step - loss: 0.0561 - accuracy: 0.9917 - val_loss: 0.1471 - val_accuracy: 0.9628
#
# Epoch 00049: val_accuracy did not improve from 0.96324
# Epoch 50/100
# 157/157 [==============================] - 5114s 33s/step - loss: 0.0516 - accuracy: 0.9942 - val_loss: 0.1458 - val_accuracy: 0.9614
#
# Epoch 00050: val_accuracy did not improve from 0.96324
# Epoch 51/100
# 157/157 [==============================] - 2203s 14s/step - loss: 0.0512 - accuracy: 0.9933 - val_loss: 0.1377 - val_accuracy: 0.9628
#
# Epoch 00051: val_accuracy did not improve from 0.96324
# Epoch 52/100
# 157/157 [==============================] - 2167s 14s/step - loss: 0.0503 - accuracy: 0.9938 - val_loss: 0.1497 - val_accuracy: 0.9619
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.002401000028476119.
#
# Epoch 00052: val_accuracy did not improve from 0.96324
# Epoch 53/100
# 157/157 [==============================] - 2167s 14s/step - loss: 0.0465 - accuracy: 0.9945 - val_loss: 0.1498 - val_accuracy: 0.9623
#
# Epoch 00053: val_accuracy did not improve from 0.96324
# Epoch 54/100
# 157/157 [==============================] - 2164s 14s/step - loss: 0.0454 - accuracy: 0.9951 - val_loss: 0.1507 - val_accuracy: 0.9609
#
# Epoch 00054: val_accuracy did not improve from 0.96324
# Epoch 55/100
# 157/157 [==============================] - 2166s 14s/step - loss: 0.0464 - accuracy: 0.9948 - val_loss: 0.1527 - val_accuracy: 0.9623
#
# Epoch 00055: val_accuracy did not improve from 0.96324
# Epoch 56/100
# 157/157 [==============================] - 2159s 14s/step - loss: 0.0426 - accuracy: 0.9965 - val_loss: 0.1492 - val_accuracy: 0.9619
#
# Epoch 00056: val_accuracy did not improve from 0.96324
# Epoch 57/100
# 157/157 [==============================] - 2159s 14s/step - loss: 0.0448 - accuracy: 0.9957 - val_loss: 0.1446 - val_accuracy: 0.9628
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.0016807000851258634.
#
# Epoch 00057: val_accuracy did not improve from 0.96324
# Epoch 58/100
# 157/157 [==============================] - 2161s 14s/step - loss: 0.0426 - accuracy: 0.9964 - val_loss: 0.1447 - val_accuracy: 0.9642
#
# Epoch 00058: val_accuracy improved from 0.96324 to 0.96415, saving model to 10-improvement-58-0.96.h5
# Epoch 59/100
# 157/157 [==============================] - 2162s 14s/step - loss: 0.0421 - accuracy: 0.9957 - val_loss: 0.1506 - val_accuracy: 0.9632
#
# Epoch 00059: val_accuracy did not improve from 0.96415
# Epoch 60/100
# 157/157 [==============================] - 2135s 14s/step - loss: 0.0417 - accuracy: 0.9965 - val_loss: 0.1388 - val_accuracy: 0.9637
#
# Epoch 00060: val_accuracy did not improve from 0.96415
# Epoch 61/100
# 157/157 [==============================] - 2136s 14s/step - loss: 0.0414 - accuracy: 0.9960 - val_loss: 0.1515 - val_accuracy: 0.9628
#
# Epoch 00061: val_accuracy did not improve from 0.96415
# Epoch 62/100
# 157/157 [==============================] - 2137s 14s/step - loss: 0.0401 - accuracy: 0.9964 - val_loss: 0.1518 - val_accuracy: 0.9623
#
# Epoch 00062: val_accuracy did not improve from 0.96415
# Epoch 63/100
# 157/157 [==============================] - 2134s 14s/step - loss: 0.0403 - accuracy: 0.9972 - val_loss: 0.1535 - val_accuracy: 0.9614
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.0011764900758862494.
#
# Epoch 00063: val_accuracy did not improve from 0.96415
# Epoch 64/100
# 157/157 [==============================] - 2136s 14s/step - loss: 0.0381 - accuracy: 0.9974 - val_loss: 0.1496 - val_accuracy: 0.9637
#
# Epoch 00064: val_accuracy did not improve from 0.96415
# Epoch 65/100
# 157/157 [==============================] - 2140s 14s/step - loss: 0.0399 - accuracy: 0.9969 - val_loss: 0.1471 - val_accuracy: 0.9614
#
# Epoch 00065: val_accuracy did not improve from 0.96415
# Epoch 66/100
# 157/157 [==============================] - 2142s 14s/step - loss: 0.0406 - accuracy: 0.9959 - val_loss: 0.1511 - val_accuracy: 0.9628
#
# Epoch 00066: val_accuracy did not improve from 0.96415

# %%
for train_index, val_index in kfold.split(np.zeros(data.shape[0]),Y):
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-4b119a10122c> in <module>
#       1 for train_index, val_index in kfold.split(np.zeros(data.shape[0]),Y):
# ----> 2     print(training_data = data.iloc[train_index])
#
# TypeError: 'training_data' is an invalid keyword argument for print()

# %%
# classifier.save('model_continue.h5')

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from keras.models import load_model
with tf.device('/cpu:0'):
    model = load_model('5_weights-improvement-31-0.96.h5')
    model.compile(optimizer= 'adam',loss = 'binary_crossentropy',metrics= ['accuracy'])

# %%
# test_datagen = ImageDataGenerator(rescale=1/255)
# # Flow training images in batches of 128 using train_datagen generator
# test_generator = test_datagen.flow_from_directory(
#         test_dir,  # This is the source directory for training images

#         ##Tamaño de imagen del validation dataset


#         target_size=(512, 512),  # All images will be resized 
#         ###


#         batch_size=128,
#         # Since we use binary_crossentropy loss, we need binary labels
#         class_mode='binary')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 256, 256, 32)      2432
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 32, 32, 256)       147712
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 16, 16, 256)       590080
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 16, 16, 512)       1180160
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 131072)            0
# _________________________________________________________________
# dense_30 (Dense)             (None, 2048)              268437504
# _________________________________________________________________
# dense_31 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dense_32 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_33 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_34 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_36 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_37 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_38 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 275,534,529
# Trainable params: 275,534,465
# Non-trainable params: 64
# _________________________________________________________________

# %%
with tf.device('/cpu:0'):
    filepath="6_continue_weights-improvement-{epoch:02d}-{val_accuracy:.2f}.h5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

    reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', mode="max", factor = 0.7, 
         patience = 5, verbose = 1, min_delta =0.00001)
    early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=30, mode='auto')

    callbacks = [reduce_lr,checkpoint,early_stop]

    batch_size = 256

    history = model.fit(train_generator,
                                       steps_per_epoch = math.ceil(train_generator.samples//batch_size),
                                  validation_data=validation_generator,  
                                       validation_steps=math.ceil(validation_generator.samples//batch_size),
                                  epochs=70,workers=-1, 
                                use_multiprocessing=True, shuffle=True, callbacks=callbacks
                                  )
# Out:
# Epoch 1/70
# 78/78 [==============================] - 792s 10s/step - loss: 0.1439 - accuracy: 0.9557 - val_loss: 0.2019 - val_accuracy: 0.9375
#
# Epoch 00001: val_accuracy improved from -inf to 0.93750, saving model to 6_continue_weights-improvement-01-0.94.h5
# Epoch 2/70
# 78/78 [==============================] - 787s 10s/step - loss: 0.1175 - accuracy: 0.9658 - val_loss: 0.1349 - val_accuracy: 0.9570
#
# Epoch 00002: val_accuracy improved from 0.93750 to 0.95703, saving model to 6_continue_weights-improvement-02-0.96.h5
# Epoch 3/70
# 78/78 [==============================] - 808s 10s/step - loss: 0.1132 - accuracy: 0.9607 - val_loss: 0.1963 - val_accuracy: 0.9434
#
# Epoch 00003: val_accuracy did not improve from 0.95703
# Epoch 4/70
# 78/78 [==============================] - 809s 10s/step - loss: 0.1560 - accuracy: 0.9442 - val_loss: 0.1287 - val_accuracy: 0.9453
#
# Epoch 00004: val_accuracy did not improve from 0.95703
# Epoch 5/70
# 78/78 [==============================] - 796s 10s/step - loss: 0.1241 - accuracy: 0.9598 - val_loss: 0.2121 - val_accuracy: 0.9453
#
# Epoch 00005: val_accuracy did not improve from 0.95703
# Epoch 6/70
# 78/78 [==============================] - 784s 10s/step - loss: 0.1464 - accuracy: 0.9567 - val_loss: 0.1566 - val_accuracy: 0.9512
#
# Epoch 00006: val_accuracy did not improve from 0.95703
# Epoch 7/70
# 78/78 [==============================] - 789s 10s/step - loss: 0.1013 - accuracy: 0.9671 - val_loss: 0.1167 - val_accuracy: 0.9551
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
#
# Epoch 00007: val_accuracy did not improve from 0.95703
# Epoch 8/70
# 78/78 [==============================] - 790s 10s/step - loss: 0.0832 - accuracy: 0.9730 - val_loss: 0.1622 - val_accuracy: 0.9473
#
# Epoch 00008: val_accuracy did not improve from 0.95703
# Epoch 9/70
# 78/78 [==============================] - 793s 10s/step - loss: 0.1085 - accuracy: 0.9620 - val_loss: 0.1713 - val_accuracy: 0.9395
#
# Epoch 00009: val_accuracy did not improve from 0.95703
# Epoch 10/70
# 78/78 [==============================] - 792s 10s/step - loss: 0.0869 - accuracy: 0.9709 - val_loss: 0.1648 - val_accuracy: 0.9512
#
# Epoch 00010: val_accuracy did not improve from 0.95703
# Epoch 11/70
# 78/78 [==============================] - 784s 10s/step - loss: 0.0864 - accuracy: 0.9690 - val_loss: 0.1652 - val_accuracy: 0.9453
#
# Epoch 00011: val_accuracy did not improve from 0.95703
# Epoch 12/70
# 78/78 [==============================] - 790s 10s/step - loss: 0.0678 - accuracy: 0.9776 - val_loss: 0.1887 - val_accuracy: 0.9434
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
#
# Epoch 00012: val_accuracy did not improve from 0.95703
# Epoch 13/70
# 78/78 [==============================] - 791s 10s/step - loss: 0.0841 - accuracy: 0.9729 - val_loss: 0.1339 - val_accuracy: 0.9590
#
# Epoch 00013: val_accuracy improved from 0.95703 to 0.95898, saving model to 6_continue_weights-improvement-13-0.96.h5
# Epoch 14/70
# 78/78 [==============================] - 789s 10s/step - loss: 0.0703 - accuracy: 0.9749 - val_loss: 0.1966 - val_accuracy: 0.9453
#
# Epoch 00014: val_accuracy did not improve from 0.95898
# Epoch 15/70
# 78/78 [==============================] - 792s 10s/step - loss: 0.0557 - accuracy: 0.9808 - val_loss: 0.1714 - val_accuracy: 0.9355
#
# Epoch 00015: val_accuracy did not improve from 0.95898
# Epoch 16/70
# 78/78 [==============================] - 794s 10s/step - loss: 0.0606 - accuracy: 0.9809 - val_loss: 0.1451 - val_accuracy: 0.9531
#
# Epoch 00016: val_accuracy did not improve from 0.95898
# Epoch 17/70
# 78/78 [==============================] - 795s 10s/step - loss: 0.0602 - accuracy: 0.9769 - val_loss: 0.1645 - val_accuracy: 0.9551
#
# Epoch 00017: val_accuracy did not improve from 0.95898
# Epoch 18/70
# 78/78 [==============================] - 784s 10s/step - loss: 0.0504 - accuracy: 0.9840 - val_loss: 0.1536 - val_accuracy: 0.9648
#
# Epoch 00018: val_accuracy improved from 0.95898 to 0.96484, saving model to 6_continue_weights-improvement-18-0.96.h5
# Epoch 19/70
# 78/78 [==============================] - 787s 10s/step - loss: 0.0528 - accuracy: 0.9844 - val_loss: 0.1478 - val_accuracy: 0.9531
#
# Epoch 00019: val_accuracy did not improve from 0.96484
# Epoch 20/70
# 78/78 [==============================] - 797s 10s/step - loss: 0.0637 - accuracy: 0.9799 - val_loss: 0.1315 - val_accuracy: 0.9648
#
# Epoch 00020: val_accuracy did not improve from 0.96484
# Epoch 21/70
# 78/78 [==============================] - 794s 10s/step - loss: 0.0508 - accuracy: 0.9839 - val_loss: 0.1420 - val_accuracy: 0.9512
#
# Epoch 00021: val_accuracy did not improve from 0.96484
# Epoch 22/70
# 78/78 [==============================] - 792s 10s/step - loss: 0.0374 - accuracy: 0.9865 - val_loss: 0.0969 - val_accuracy: 0.9688
#
# Epoch 00022: val_accuracy improved from 0.96484 to 0.96875, saving model to 6_continue_weights-improvement-22-0.97.h5
# Epoch 23/70
# 78/78 [==============================] - 796s 10s/step - loss: 0.0479 - accuracy: 0.9822 - val_loss: 0.1663 - val_accuracy: 0.9492
#
# Epoch 00023: val_accuracy did not improve from 0.96875
# Epoch 24/70
# 78/78 [==============================] - 800s 10s/step - loss: 0.0475 - accuracy: 0.9832 - val_loss: 0.1493 - val_accuracy: 0.9473
#
# Epoch 00024: val_accuracy did not improve from 0.96875
# Epoch 25/70
# 78/78 [==============================] - 794s 10s/step - loss: 0.0389 - accuracy: 0.9888 - val_loss: 0.2522 - val_accuracy: 0.9355
#
# Epoch 00025: val_accuracy did not improve from 0.96875
# Epoch 26/70
# 78/78 [==============================] - 787s 10s/step - loss: 0.0459 - accuracy: 0.9861 - val_loss: 0.1519 - val_accuracy: 0.9434
#
# Epoch 00026: val_accuracy did not improve from 0.96875
# Epoch 27/70
# 78/78 [==============================] - 790s 10s/step - loss: 0.0506 - accuracy: 0.9864 - val_loss: 0.1824 - val_accuracy: 0.9512
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.00034300000406801696.
#
# Epoch 00027: val_accuracy did not improve from 0.96875
# Epoch 28/70
# 78/78 [==============================] - 792s 10s/step - loss: 0.0612 - accuracy: 0.9801 - val_loss: 0.2151 - val_accuracy: 0.9512
#
# Epoch 00028: val_accuracy did not improve from 0.96875
# Epoch 29/70
# 78/78 [==============================] - 787s 10s/step - loss: 0.0514 - accuracy: 0.9831 - val_loss: 0.1727 - val_accuracy: 0.9648
#
# Epoch 00029: val_accuracy did not improve from 0.96875
# Epoch 30/70
# 78/78 [==============================] - 793s 10s/step - loss: 0.0298 - accuracy: 0.9898 - val_loss: 0.1495 - val_accuracy: 0.9707
#
# Epoch 00030: val_accuracy improved from 0.96875 to 0.97070, saving model to 6_continue_weights-improvement-30-0.97.h5
# Epoch 31/70
# 78/78 [==============================] - 802s 10s/step - loss: 0.0268 - accuracy: 0.9892 - val_loss: 0.1822 - val_accuracy: 0.9570
#
# Epoch 00031: val_accuracy did not improve from 0.97070
# Epoch 32/70
# 78/78 [==============================] - 794s 10s/step - loss: 0.0424 - accuracy: 0.9870 - val_loss: 0.1599 - val_accuracy: 0.9570
#
# Epoch 00032: val_accuracy did not improve from 0.97070
# Epoch 33/70
# 78/78 [==============================] - 791s 10s/step - loss: 0.0311 - accuracy: 0.9903 - val_loss: 0.1446 - val_accuracy: 0.9570
#
# Epoch 00033: val_accuracy did not improve from 0.97070
# Epoch 34/70
# 78/78 [==============================] - 789s 10s/step - loss: 0.0254 - accuracy: 0.9916 - val_loss: 0.1929 - val_accuracy: 0.9492
#
# Epoch 00034: val_accuracy did not improve from 0.97070
# Epoch 35/70
# 78/78 [==============================] - 788s 10s/step - loss: 0.0195 - accuracy: 0.9941 - val_loss: 0.2958 - val_accuracy: 0.9531
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.00024009999469853935.
#
# Epoch 00035: val_accuracy did not improve from 0.97070
# Epoch 36/70
# 78/78 [==============================] - 794s 10s/step - loss: 0.0181 - accuracy: 0.9939 - val_loss: 0.1785 - val_accuracy: 0.9492
#
# Epoch 00036: val_accuracy did not improve from 0.97070
# Epoch 37/70
# 78/78 [==============================] - 793s 10s/step - loss: 0.0194 - accuracy: 0.9934 - val_loss: 0.2126 - val_accuracy: 0.9531
#
# Epoch 00037: val_accuracy did not improve from 0.97070
# Epoch 38/70
# 78/78 [==============================] - 786s 10s/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.1803 - val_accuracy: 0.9609
#
# Epoch 00038: val_accuracy did not improve from 0.97070
# Epoch 39/70
# 78/78 [==============================] - 796s 10s/step - loss: 0.0168 - accuracy: 0.9948 - val_loss: 0.1470 - val_accuracy: 0.9570
#
# Epoch 00039: val_accuracy did not improve from 0.97070
# Epoch 40/70
# 78/78 [==============================] - 795s 10s/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.2420 - val_accuracy: 0.9648
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00016806999628897755.
#
# Epoch 00040: val_accuracy did not improve from 0.97070
# Epoch 41/70
# 78/78 [==============================] - 788s 10s/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.3848 - val_accuracy: 0.9512
#
# Epoch 00041: val_accuracy did not improve from 0.97070
# Epoch 42/70
# 78/78 [==============================] - 794s 10s/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.2117 - val_accuracy: 0.9453
#
# Epoch 00042: val_accuracy did not improve from 0.97070
# Epoch 43/70
# 78/78 [==============================] - 793s 10s/step - loss: 0.0092 - accuracy: 0.9984 - val_loss: 0.3930 - val_accuracy: 0.9434
#
# Epoch 00043: val_accuracy did not improve from 0.97070
# Epoch 44/70
# 78/78 [==============================] - 793s 10s/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.3352 - val_accuracy: 0.9551
#
# Epoch 00044: val_accuracy did not improve from 0.97070
# Epoch 45/70
# 78/78 [==============================] - 795s 10s/step - loss: 0.0078 - accuracy: 0.9967 - val_loss: 0.2398 - val_accuracy: 0.9609
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.00011764899536501615.
#
# Epoch 00045: val_accuracy did not improve from 0.97070
# Epoch 46/70
# 78/78 [==============================] - 802s 10s/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.2535 - val_accuracy: 0.9707
#
# Epoch 00046: val_accuracy did not improve from 0.97070
# Epoch 47/70
# 78/78 [==============================] - 806s 10s/step - loss: 0.0040 - accuracy: 0.9984 - val_loss: 0.3744 - val_accuracy: 0.9395
#
# Epoch 00047: val_accuracy did not improve from 0.97070
# Epoch 48/70
# 78/78 [==============================] - 798s 10s/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.2884 - val_accuracy: 0.9570
#
# Epoch 00048: val_accuracy did not improve from 0.97070
# Epoch 49/70
# 78/78 [==============================] - 794s 10s/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.1809 - val_accuracy: 0.9609
#
# Epoch 00049: val_accuracy did not improve from 0.97070
# Epoch 50/70
# 78/78 [==============================] - 792s 10s/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.3450 - val_accuracy: 0.9453
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 8.235429777414538e-05.
#
# Epoch 00050: val_accuracy did not improve from 0.97070
# Epoch 51/70
# 78/78 [==============================] - 793s 10s/step - loss: 0.0106 - accuracy: 0.9971 - val_loss: 0.2736 - val_accuracy: 0.9590
#
# Epoch 00051: val_accuracy did not improve from 0.97070
# Epoch 52/70
# 78/78 [==============================] - 793s 10s/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.4344 - val_accuracy: 0.9473
#
# Epoch 00052: val_accuracy did not improve from 0.97070

# %%
batch_size= 32
y = model.predict_generator(test_generator,steps= math.ceil(test_generator.samples//batch_size),workers=8)

# %%
scoreSeg = model.evaluate_generator(test_generator,862)
print("Accuracy = ",scoreSeg[1])
# Out:
# Accuracy =  0.9790712594985962

# %%
loss,acc = model.evaluate(test_generator)
print("restored model , accuracy in the test set :  ",acc)
# Out:
# 27/27 [==============================] - 45s 2s/step
# restored model , accuracy in the test set :   0.9791183471679688

# %%
# Get the ground truth from generator
ground_truth = test_generator.classes
predictions = model.predict_generator(test_generator, steps=test_generator.samples/test_generator.batch_size,verbose=1)
predicted_classes = np.around(predictions) 
predicted_classes = predicted_classes.astype(int)
predicted_classes = predicted_classes[:,0]
errors = np.where(predicted_classes != ground_truth)[0]
print("number of errors = {}/{}".format(len(errors),test_generator.samples))
cm = confusion_matrix(ground_truth, predicted_classes)
data = confusion_matrix(ground_truth, predicted_classes)
print(cm)
df_cm = pd.DataFrame(data, columns=np.unique(ground_truth), index = np.unique(ground_truth))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,10))
sns.set(font_scale=2)#for label size
sns.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 16})# font size
# Out:
# 27/26 [==============================] - 46s 2s/step
# number of errors = 346/862
# [[ 67 174]
#  [172 449]]

# %%
from sklearn.metrics import classification_report
print(classification_report(ground_truth, predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.28      0.28       241
#            1       0.72      0.72      0.72       621
#
#     accuracy                           0.60       862
#    macro avg       0.50      0.50      0.50       862
# weighted avg       0.60      0.60      0.60       862

# %%
from keras.preprocessing import image


path='dataset/cam1_splitted/test/OK/imagen_2020_12_18_1137_24318.png' 
img=image.load_img(path, target_size=(512, 512))
plt.imshow(img)  
x=image.img_to_array(img)
x=np.expand_dims(x, axis=0)
images = np.vstack([x])
  
classes = model.predict(images, batch_size=10)
  
print(classes)
if classes[0]>0.5:
    print( "OK")
    
else:
    print( " NOT OK")
# Out:
# [[1.]]
# OK

# %%
import PIL
from keras.preprocessing import image
import glob
# %matplotlib inline

for i,filename in enumerate(glob.glob("dataset/cam1_splitted/test/OK/*.png"), 1):
    img=image.load_img(filename, target_size=(512, 512))
#     plt.figure()
   
    
    x=image.img_to_array(img)
    x=np.expand_dims(x, axis=0)
    images = np.vstack([x])
  
    classes = model.predict(images, batch_size=10)
  
    if classes[0]<0.5:
#         plt.axis('off')
#         plt.grid(b=None)
#         plt.figure(figsize=((10,10)))
# #         plt.subplot(300, 4, i+1)
        plt.imshow(img)
        plt.show()

# %%
for i,filename in enumerate(glob.glob("dataset/cam1_splitted/test/NOT_OK/*.png")):
    img=image.load_img(filename, target_size=(512, 512))
#     plt.figure()
   
#     print(i) 
    x=image.img_to_array(img)
    x=np.expand_dims(x, axis=0)
    images = np.vstack([x])
  
    classes = model.predict(images, batch_size=10)
#     print(classes[0])
    if classes[0]>0.5:
#         plt.axis('off')
#         plt.grid(b=None)
#         plt.figure(figsize=((10,10)))
# #         plt.subplot(300, 4, i+1)
        plt.imshow(img)
        plt.show()
